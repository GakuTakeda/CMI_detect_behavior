# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
sol = np.load("/mnt/c/Users/tkdgk/CMI_detect_behavior-1/Macro/outputs/2025-07-14/16-20-20/output/fold1solution.npy")
sub = np.load("/mnt/c/Users/tkdgk/CMI_detect_behavior-1/Macro/outputs/2025-07-14/16-20-20/output/fold1submission.npy")

# %%
plt.figure(figsize=(10, 6))
plt.hist(sub, color="C0")
plt.hist(sol, color="C1", alpha=0.5)

plt.xticks(rotation=45, ha='right')
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'Forehead - pull hairline'),
#   Text(1, 0, 'Neck - scratch'),
#   Text(2, 0, 'Eyebrow - pull hair'),
#   Text(3, 0, 'Above ear - pull hair'),
#   Text(4, 0, 'Cheek - pinch skin'),
#   Text(5, 0, 'Forehead - scratch'),
#   Text(6, 0, 'Neck - pinch skin'),
#   Text(7, 0, 'Eyelash - pull hair')])

# %%
solutions = [] # Create an empty list to store the solutions
submissions = []

for i in range(1, 5): # Assuming num_folds is defined elsewhere, e.g., num_folds = 5
    sol_path = f"/mnt/c/Users/tkdgk/CMI_detect_behavior-1/Macro/outputs/2025-07-12/03-40-23/output/fold{i}solution.npy"
    sub_path = f"/mnt/c/Users/tkdgk/CMI_detect_behavior-1/Macro/outputs/2025-07-12/03-40-23/output/fold{i}submission.npy"
    solution = np.load(sol_path)
    solutions.append(solution)
    submission = np.load(sub_path)
    submissions.append(submission)

# %%
pair = []
for i, sub in enumerate(submission[0]):
    if sub !=solution[0][i]:
        print(sub, solution[0][i])
        pair.append([sub, solution[0][i]])

# %%
pair
# Out:
# []

# %%
sub = []
sol = []
for b in submissions[0]:
    if b in ["Cheek - pinch skin", "Neck - scratch", "Above ear - pull hair", "Forehead - pull hairline"]:
        continue
    sub.append(b)

for b in solutions[0]:
    if b in ["Cheek - pinch skin", "Neck - scratch", "Above ear - pull hair", "Forehead - pull hairline"]:
        continue
    sol.append(b)

# %%
plt.figure(figsize=(10, 6))
plt.hist(sub, color="C0")
plt.hist(sol, color="C1", alpha=0.5)

plt.xticks(rotation=45, ha='right')
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'Forehead - scratch'),
#   Text(1, 0, 'Eyebrow - pull hair'),
#   Text(2, 0, 'Neck - pinch skin'),
#   Text(3, 0, 'Eyelash - pull hair')])

# %%
plt.figure(figsize=(10, 6))
plt.hist(submissions[0], color="C0")
plt.hist(solutions[0], color="C1", alpha=0.5)

plt.xticks(rotation=45, ha='right')
# Out:
# ([0, 1, 2, 3, 4, 5, 6, 7],
#  [Text(0, 0, 'Forehead - scratch'),
#   Text(1, 0, 'Eyebrow - pull hair'),
#   Text(2, 0, 'Neck - pinch skin'),
#   Text(3, 0, 'Eyelash - pull hair'),
#   Text(4, 0, 'Forehead - pull hairline'),
#   Text(5, 0, 'Cheek - pinch skin'),
#   Text(6, 0, 'Neck - scratch'),
#   Text(7, 0, 'Above ear - pull hair')])

# %%
submission
# Out:
# array(['Neck - pinch skin', 'Above ear - pull hair',
#        'Above ear - pull hair', ..., 'Eyelash - pull hair',
#        'Eyelash - pull hair', 'Cheek - pinch skin'],
#       shape=(1022,), dtype='<U24')
